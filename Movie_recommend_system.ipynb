# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyeon712/Movie-Recommend-System/blob/main/Movie_recommend_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
credits = pd.read_csv("/content/drive/MyDrive/Movie Recommend System/tmdb_5000_credits.csv")
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies = pd.read_csv("/content/drive/MyDrive/Movie Recommend System/tmdb_5000_movies.csv")
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
df = movies.merge(credits,on='title')
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4804                                                NaN    9367
# 4805                                                NaN   72766
# 4806  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4807                        http://shanghaicalling.com/  126186
# 4808                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4804  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4805                                                 []                en
# 4806  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4807                                                 []                en
# 4808  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4804  El Mariachi just wants to play his guitar and ...   14.269792
# 4805  A newlywed couple's honeymoon is upended by th...    0.642552
# 4806  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4807  When ambitious New York attorney Sam is sent t...    0.857008
# 4808  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  ... runtime  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
# ...                                                 ...  ...     ...
# 4804           [{"name": "Columbia Pictures", "id": 5}]  ...    81.0
# 4805                                                 []  ...    85.0
# 4806  [{"name": "Front Street Pictures", "id": 3958}...  ...   120.0
# 4807                                                 []  ...    98.0
# 4808  [{"name": "rusty bear entertainment", "id": 87...  ...    90.0
#
#                                        spoken_languages    status  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1              [{"iso_639_1": "en", "name": "English"}]  Released
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3              [{"iso_639_1": "en", "name": "English"}]  Released
# 4              [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                 ...       ...
# 4804      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 4805                                                 []  Released
# 4806           [{"iso_639_1": "en", "name": "English"}]  Released
# 4807           [{"iso_639_1": "en", "name": "English"}]  Released
# 4808           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4804  He didn't come looking for trouble, but troubl...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806                                                NaN
# 4807                           A New Yorker in Shanghai
# 4808                                                NaN
#
#                                          title vote_average vote_count  \
# 0                                       Avatar          7.2      11800
# 1     Pirates of the Caribbean: At World's End          6.9       4500
# 2                                      Spectre          6.3       4466
# 3                        The Dark Knight Rises          7.6       9106
# 4                                  John Carter          6.1       2124
# ...                                        ...          ...        ...
# 4804                               El Mariachi          6.6        238
# 4805                                 Newlyweds          5.9          5
# 4806                 Signed, Sealed, Delivered          7.0          6
# 4807                          Shanghai Calling          5.7          7
# 4808                         My Date with Drew          6.3         16
#
#      movie_id                                               cast  \
# 0       19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1         285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2      206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3       49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...       ...                                                ...
# 4804     9367  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805    72766  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806   231617  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807   126186  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808    25975  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4809 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'cast', 'crew'],
#       dtype='object')

# %% [markdown]
# #### status 값이 released만 남겨놓기

# %%
df = df[df['status']=='Released']
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4804                                                NaN    9367
# 4805                                                NaN   72766
# 4806  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4807                        http://shanghaicalling.com/  126186
# 4808                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4804  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4805                                                 []                en
# 4806  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4807                                                 []                en
# 4808  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4804  El Mariachi just wants to play his guitar and ...   14.269792
# 4805  A newlywed couple's honeymoon is upended by th...    0.642552
# 4806  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4807  When ambitious New York attorney Sam is sent t...    0.857008
# 4808  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  ... runtime  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
# ...                                                 ...  ...     ...
# 4804           [{"name": "Columbia Pictures", "id": 5}]  ...    81.0
# 4805                                                 []  ...    85.0
# 4806  [{"name": "Front Street Pictures", "id": 3958}...  ...   120.0
# 4807                                                 []  ...    98.0
# 4808  [{"name": "rusty bear entertainment", "id": 87...  ...    90.0
#
#                                        spoken_languages    status  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1              [{"iso_639_1": "en", "name": "English"}]  Released
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3              [{"iso_639_1": "en", "name": "English"}]  Released
# 4              [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                 ...       ...
# 4804      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 4805                                                 []  Released
# 4806           [{"iso_639_1": "en", "name": "English"}]  Released
# 4807           [{"iso_639_1": "en", "name": "English"}]  Released
# 4808           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4804  He didn't come looking for trouble, but troubl...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806                                                NaN
# 4807                           A New Yorker in Shanghai
# 4808                                                NaN
#
#                                          title vote_average vote_count  \
# 0                                       Avatar          7.2      11800
# 1     Pirates of the Caribbean: At World's End          6.9       4500
# 2                                      Spectre          6.3       4466
# 3                        The Dark Knight Rises          7.6       9106
# 4                                  John Carter          6.1       2124
# ...                                        ...          ...        ...
# 4804                               El Mariachi          6.6        238
# 4805                                 Newlyweds          5.9          5
# 4806                 Signed, Sealed, Delivered          7.0          6
# 4807                          Shanghai Calling          5.7          7
# 4808                         My Date with Drew          6.3         16
#
#      movie_id                                               cast  \
# 0       19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1         285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2      206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3       49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...       ...                                                ...
# 4804     9367  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805    72766  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806   231617  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807   126186  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808    25975  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4801 rows x 23 columns]

# %% [markdown]
# #### 원하는 컬럼만 다시 뽑은 DF 데이터셋 생성

# %%
DF = df[['id','title','genres','keywords', 'status','overview','tagline','popularity','release_date', 'cast', 'crew']]
DF
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4804  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807                                                 []
# 4808                [{"id": 99, "name": "Documentary"}]
#
#                                                keywords    status  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...  Released
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...  Released
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...  Released
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...  Released
# 4     [{"id": 818, "name": "based on novel"}, {"id":...  Released
# ...                                                 ...       ...
# 4804  [{"id": 5616, "name": "united states\u2013mexi...  Released
# 4805                                                 []  Released
# 4806  [{"id": 248, "name": "date"}, {"id": 699, "nam...  Released
# 4807                                                 []  Released
# 4808  [{"id": 1523, "name": "obsession"}, {"id": 224...  Released
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4804  El Mariachi just wants to play his guitar and ...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806  "Signed, Sealed, Delivered" introduces a dedic...
# 4807  When ambitious New York attorney Sam is sent t...
# 4808  Ever since the second grade when he first saw ...
#
#                                                 tagline  popularity  \
# 0                           Enter the World of Pandora.  150.437577
# 1        At the end of the world, the adventure begins.  139.082615
# 2                                 A Plan No One Escapes  107.376788
# 3                                       The Legend Ends  112.312950
# 4                  Lost in our world, found in another.   43.926995
# ...                                                 ...         ...
# 4804  He didn't come looking for trouble, but troubl...   14.269792
# 4805  A newlywed couple's honeymoon is upended by th...    0.642552
# 4806                                                NaN    1.444476
# 4807                           A New Yorker in Shanghai    0.857008
# 4808                                                NaN    1.929883
#
#      release_date                                               cast  \
# 0      2009-12-10  [{"cast_id": 242, "character": "Jake Sully", "...
# 1      2007-05-19  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2      2015-10-26  [{"cast_id": 1, "character": "James Bond", "cr...
# 3      2012-07-16  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4      2012-03-07  [{"cast_id": 5, "character": "John Carter", "c...
# ...           ...                                                ...
# 4804   1992-09-04  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805   2011-12-26  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806   2013-10-13  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807   2012-05-03  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808   2005-08-05  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4801 rows x 11 columns]

# %%
# tagline 널값 844개, overview 3개 제외 나머지는 널값 없음.

DF.isna().sum()
# Out:
# id                0
# title             0
# genres            0
# keywords          0
# status            0
# overview          3
# tagline         838
# popularity        0
# release_date      1
# cast              0
# crew              0
# dtype: int64

# %%
# 정렬을 위한 컬럼에서는 널값이 있으면 안되기 때문에 삭제

DF = DF.dropna(subset=['release_date'])
DF
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4804  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807                                                 []
# 4808                [{"id": 99, "name": "Documentary"}]
#
#                                                keywords    status  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...  Released
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...  Released
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...  Released
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...  Released
# 4     [{"id": 818, "name": "based on novel"}, {"id":...  Released
# ...                                                 ...       ...
# 4804  [{"id": 5616, "name": "united states\u2013mexi...  Released
# 4805                                                 []  Released
# 4806  [{"id": 248, "name": "date"}, {"id": 699, "nam...  Released
# 4807                                                 []  Released
# 4808  [{"id": 1523, "name": "obsession"}, {"id": 224...  Released
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4804  El Mariachi just wants to play his guitar and ...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806  "Signed, Sealed, Delivered" introduces a dedic...
# 4807  When ambitious New York attorney Sam is sent t...
# 4808  Ever since the second grade when he first saw ...
#
#                                                 tagline  popularity  \
# 0                           Enter the World of Pandora.  150.437577
# 1        At the end of the world, the adventure begins.  139.082615
# 2                                 A Plan No One Escapes  107.376788
# 3                                       The Legend Ends  112.312950
# 4                  Lost in our world, found in another.   43.926995
# ...                                                 ...         ...
# 4804  He didn't come looking for trouble, but troubl...   14.269792
# 4805  A newlywed couple's honeymoon is upended by th...    0.642552
# 4806                                                NaN    1.444476
# 4807                           A New Yorker in Shanghai    0.857008
# 4808                                                NaN    1.929883
#
#      release_date                                               cast  \
# 0      2009-12-10  [{"cast_id": 242, "character": "Jake Sully", "...
# 1      2007-05-19  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2      2015-10-26  [{"cast_id": 1, "character": "James Bond", "cr...
# 3      2012-07-16  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4      2012-03-07  [{"cast_id": 5, "character": "John Carter", "c...
# ...           ...                                                ...
# 4804   1992-09-04  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805   2011-12-26  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806   2013-10-13  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807   2012-05-03  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808   2005-08-05  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4800 rows x 11 columns]

# %% [markdown]
# #### release_data에서 년도만 추출

# %%
DF['release_date'] = pd.to_datetime(DF['release_date'])
DF['release_date'] = DF['release_date'].dt.year
DF.head()
# Out:
# <ipython-input-11-21e7ce5657bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['release_date'] = pd.to_datetime(DF['release_date'])
# <ipython-input-11-21e7ce5657bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['release_date'] = DF['release_date'].dt.year
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords    status  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...  Released
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...  Released
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...  Released
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...  Released
# 4  [{"id": 818, "name": "based on novel"}, {"id":...  Released
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           tagline  popularity  release_date  \
# 0                     Enter the World of Pandora.  150.437577          2009
# 1  At the end of the world, the adventure begins.  139.082615          2007
# 2                           A Plan No One Escapes  107.376788          2015
# 3                                 The Legend Ends  112.312950          2012
# 4            Lost in our world, found in another.   43.926995          2012
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# #### name 값 추출

# %%
import ast

def convert(obj):
    l = []  # List to store name
    for i in ast.literal_eval(obj):   #ast.literal_eval() convert str into list
        l.append(i['name'])
    return l

# %%
DF['genres'] = DF['genres'].apply(convert)
DF['keywords'] = DF['keywords'].apply(convert)
DF.head()
# Out:
# <ipython-input-13-daa1ba862e83>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['genres'] = DF['genres'].apply(convert)
# <ipython-input-13-daa1ba862e83>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['keywords'] = DF['keywords'].apply(convert)
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords    status  \
# 0  [culture clash, future, space war, space colon...  Released
# 1  [ocean, drug abuse, exotic island, east india ...  Released
# 2  [spy, based on novel, secret agent, sequel, mi...  Released
# 3  [dc comics, crime fighter, terrorist, secret i...  Released
# 4  [based on novel, mars, medallion, space travel...  Released
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           tagline  popularity  release_date  \
# 0                     Enter the World of Pandora.  150.437577          2009
# 1  At the end of the world, the adventure begins.  139.082615          2007
# 2                           A Plan No One Escapes  107.376788          2015
# 3                                 The Legend Ends  112.312950          2012
# 4            Lost in our world, found in another.   43.926995          2012
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# #### 주요 3명의 캐스트만 추출하기 위한 코드

# %%
def convert3(obj):
    l =[]
    counter =0
    for i in ast.literal_eval(obj):
        if counter !=3:   # Limit 3 only
            l.append(i['name'])
            counter +=1
        else:
            break
    return l

# %%
DF['cast'] = DF['cast'].apply(convert3)
# Out:
# <ipython-input-15-e166dc61b802>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['cast'] = DF['cast'].apply(convert3)

# %% [markdown]
# #### 감독 이름 추출

# %%
def extract_director(obj):
    l = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            l.append(i['name'])
            break
    return l

# %%
DF['crew'] = DF['crew'].apply(extract_director)
# Out:
# <ipython-input-17-5890c8152da0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['crew'] = DF['crew'].apply(extract_director)

# %%
DF.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords    status  \
# 0  [culture clash, future, space war, space colon...  Released
# 1  [ocean, drug abuse, exotic island, east india ...  Released
# 2  [spy, based on novel, secret agent, sequel, mi...  Released
# 3  [dc comics, crime fighter, terrorist, secret i...  Released
# 4  [based on novel, mars, medallion, space travel...  Released
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           tagline  popularity  release_date  \
# 0                     Enter the World of Pandora.  150.437577          2009
# 1  At the end of the world, the adventure begins.  139.082615          2007
# 2                           A Plan No One Escapes  107.376788          2015
# 3                                 The Legend Ends  112.312950          2012
# 4            Lost in our world, found in another.   43.926995          2012
#
#                                                cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]

# %% [markdown]
# #### 단어 분리
# * overview, tagline 문장을 분리한 단어들을 리스트로 묶음.
# * 널값은 빈리스트를 반환

# %%
DF['overview'] = [x.split() if pd.notnull(x) else [] for x in DF['overview']]
DF['tagline'] = [x.split() if pd.notnull(x) else [] for x in DF['tagline']]
DF.head()
# Out:
# <ipython-input-19-3b568dc90ed3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['overview'] = [x.split() if pd.notnull(x) else [] for x in DF['overview']]
# <ipython-input-19-3b568dc90ed3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['tagline'] = [x.split() if pd.notnull(x) else [] for x in DF['tagline']]
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords    status  \
# 0  [culture clash, future, space war, space colon...  Released
# 1  [ocean, drug abuse, exotic island, east india ...  Released
# 2  [spy, based on novel, secret agent, sequel, mi...  Released
# 3  [dc comics, crime fighter, terrorist, secret i...  Released
# 4  [based on novel, mars, medallion, space travel...  Released
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                              tagline  popularity  \
# 0                  [Enter, the, World, of, Pandora.]  150.437577
# 1  [At, the, end, of, the, world,, the, adventure...  139.082615
# 2                        [A, Plan, No, One, Escapes]  107.376788
# 3                                [The, Legend, Ends]  112.312950
# 4       [Lost, in, our, world,, found, in, another.]   43.926995
#
#    release_date                                              cast  \
# 0          2009  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1          2007     [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2          2015      [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3          2012      [Christian Bale, Michael Caine, Gary Oldman]
# 4          2012    [Taylor Kitsch, Lynn Collins, Samantha Morton]
#
#                   crew
# 0      [James Cameron]
# 1     [Gore Verbinski]
# 2         [Sam Mendes]
# 3  [Christopher Nolan]
# 4     [Andrew Stanton]

# %% [markdown]
# #### 공백 제거

# %%
DF['genres'] = DF['genres'].apply(lambda x: [i.replace(" ","") for i in x])
DF['keywords'] = DF['keywords'].apply(lambda x: [i.replace(" ","") for i in x])
DF['overview'] = DF['overview'].apply(lambda x: [i.replace(" ","") for i in x])
DF['tagline'] = DF['tagline'].apply(lambda x: [i.replace(" ","") for i in x])
DF['cast'] = DF['cast'].apply(lambda x: [i.replace(" ","") for i in x])
DF['crew'] = DF['crew'].apply(lambda x: [i.replace(" ","") for i in x])
# Out:
# <ipython-input-20-f24e56b2adee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['genres'] = DF['genres'].apply(lambda x: [i.replace(" ","") for i in x])
# <ipython-input-20-f24e56b2adee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['keywords'] = DF['keywords'].apply(lambda x: [i.replace(" ","") for i in x])
# <ipython-input-20-f24e56b2adee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['overview'] = DF['overview'].apply(lambda x: [i.replace(" ","") for i in x])
# <ipython-input-20-f24e56b2adee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['tagline'] = DF['tagline'].apply(lambda x: [i.replace(" ","") for i in x])
# <ipython-input-20-f24e56b2adee>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['cast'] = DF['cast'].apply(lambda x: [i.replace(" ","") for i in x])
# <ipython-input-20-f24e56b2adee>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['crew'] = DF['crew'].apply(lambda x: [i.replace(" ","") for i in x])

# %%
DF
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                             genres  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]
# 1                     [Adventure, Fantasy, Action]
# 2                       [Action, Adventure, Crime]
# 3                 [Action, Crime, Drama, Thriller]
# 4              [Action, Adventure, ScienceFiction]
# ...                                            ...
# 4804                     [Action, Crime, Thriller]
# 4805                             [Comedy, Romance]
# 4806             [Comedy, Drama, Romance, TVMovie]
# 4807                                            []
# 4808                                 [Documentary]
#
#                                                keywords    status  \
# 0     [cultureclash, future, spacewar, spacecolony, ...  Released
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...  Released
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...  Released
# 3     [dccomics, crimefighter, terrorist, secretiden...  Released
# 4     [basedonnovel, mars, medallion, spacetravel, p...  Released
# ...                                                 ...       ...
# 4804  [unitedstates–mexicobarrier, legs, arms, paper...  Released
# 4805                                                 []  Released
# 4806  [date, loveatfirstsight, narration, investigat...  Released
# 4807                                                 []  Released
# 4808           [obsession, camcorder, crush, dreamgirl]  Released
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# 4     [John, Carter, is, a, war-weary,, former, mili...
# ...                                                 ...
# 4804  [El, Mariachi, just, wants, to, play, his, gui...
# 4805  [A, newlywed, couple's, honeymoon, is, upended...
# 4806  ["Signed,, Sealed,, Delivered", introduces, a,...
# 4807  [When, ambitious, New, York, attorney, Sam, is...
# 4808  [Ever, since, the, second, grade, when, he, fi...
#
#                                                 tagline  popularity  \
# 0                     [Enter, the, World, of, Pandora.]  150.437577
# 1     [At, the, end, of, the, world,, the, adventure...  139.082615
# 2                           [A, Plan, No, One, Escapes]  107.376788
# 3                                   [The, Legend, Ends]  112.312950
# 4          [Lost, in, our, world,, found, in, another.]   43.926995
# ...                                                 ...         ...
# 4804  [He, didn't, come, looking, for, trouble,, but...   14.269792
# 4805  [A, newlywed, couple's, honeymoon, is, upended...    0.642552
# 4806                                                 []    1.444476
# 4807                     [A, New, Yorker, in, Shanghai]    0.857008
# 4808                                                 []    1.929883
#
#       release_date                                            cast  \
# 0             2009   [SamWorthington, ZoeSaldana, SigourneyWeaver]
# 1             2007      [JohnnyDepp, OrlandoBloom, KeiraKnightley]
# 2             2015       [DanielCraig, ChristophWaltz, LéaSeydoux]
# 3             2012       [ChristianBale, MichaelCaine, GaryOldman]
# 4             2012     [TaylorKitsch, LynnCollins, SamanthaMorton]
# ...            ...                                             ...
# 4804          1992  [CarlosGallardo, JaimedeHoyos, PeterMarquardt]
# 4805          2011       [EdwardBurns, KerryBishé, MarshaDietlein]
# 4806          2013         [EricMabius, KristinBooth, CrystalLowe]
# 4807          2012          [DanielHenney, ElizaCoupe, BillPaxton]
# 4808          2005  [DrewBarrymore, BrianHerzlinger, CoreyFeldman]
#
#                     crew
# 0         [JamesCameron]
# 1        [GoreVerbinski]
# 2            [SamMendes]
# 3     [ChristopherNolan]
# 4        [AndrewStanton]
# ...                  ...
# 4804   [RobertRodriguez]
# 4805       [EdwardBurns]
# 4806        [ScottSmith]
# 4807        [DanielHsia]
# 4808   [BrianHerzlinger]
#
# [4800 rows x 11 columns]

# %% [markdown]
# #### 새로운 컬럼 생성

# %%
DF.columns
# Out:
# Index(['id', 'title', 'genres', 'keywords', 'status', 'overview', 'tagline',
#        'popularity', 'release_date', 'cast', 'crew'],
#       dtype='object')

# %%
DF['tags'] = DF['genres'] + DF['overview'] + DF['keywords'] + DF['tagline']  + DF['cast'] + DF['crew']
DF
# Out:
# <ipython-input-23-31e1e167b993>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['tags'] = DF['genres'] + DF['overview'] + DF['keywords'] + DF['tagline']  + DF['cast'] + DF['crew']
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                             genres  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]
# 1                     [Adventure, Fantasy, Action]
# 2                       [Action, Adventure, Crime]
# 3                 [Action, Crime, Drama, Thriller]
# 4              [Action, Adventure, ScienceFiction]
# ...                                            ...
# 4804                     [Action, Crime, Thriller]
# 4805                             [Comedy, Romance]
# 4806             [Comedy, Drama, Romance, TVMovie]
# 4807                                            []
# 4808                                 [Documentary]
#
#                                                keywords    status  \
# 0     [cultureclash, future, spacewar, spacecolony, ...  Released
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...  Released
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...  Released
# 3     [dccomics, crimefighter, terrorist, secretiden...  Released
# 4     [basedonnovel, mars, medallion, spacetravel, p...  Released
# ...                                                 ...       ...
# 4804  [unitedstates–mexicobarrier, legs, arms, paper...  Released
# 4805                                                 []  Released
# 4806  [date, loveatfirstsight, narration, investigat...  Released
# 4807                                                 []  Released
# 4808           [obsession, camcorder, crush, dreamgirl]  Released
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# 4     [John, Carter, is, a, war-weary,, former, mili...
# ...                                                 ...
# 4804  [El, Mariachi, just, wants, to, play, his, gui...
# 4805  [A, newlywed, couple's, honeymoon, is, upended...
# 4806  ["Signed,, Sealed,, Delivered", introduces, a,...
# 4807  [When, ambitious, New, York, attorney, Sam, is...
# 4808  [Ever, since, the, second, grade, when, he, fi...
#
#                                                 tagline  popularity  \
# 0                     [Enter, the, World, of, Pandora.]  150.437577
# 1     [At, the, end, of, the, world,, the, adventure...  139.082615
# 2                           [A, Plan, No, One, Escapes]  107.376788
# 3                                   [The, Legend, Ends]  112.312950
# 4          [Lost, in, our, world,, found, in, another.]   43.926995
# ...                                                 ...         ...
# 4804  [He, didn't, come, looking, for, trouble,, but...   14.269792
# 4805  [A, newlywed, couple's, honeymoon, is, upended...    0.642552
# 4806                                                 []    1.444476
# 4807                     [A, New, Yorker, in, Shanghai]    0.857008
# 4808                                                 []    1.929883
#
#       release_date                                            cast  \
# 0             2009   [SamWorthington, ZoeSaldana, SigourneyWeaver]
# 1             2007      [JohnnyDepp, OrlandoBloom, KeiraKnightley]
# 2             2015       [DanielCraig, ChristophWaltz, LéaSeydoux]
# 3             2012       [ChristianBale, MichaelCaine, GaryOldman]
# 4             2012     [TaylorKitsch, LynnCollins, SamanthaMorton]
# ...            ...                                             ...
# 4804          1992  [CarlosGallardo, JaimedeHoyos, PeterMarquardt]
# 4805          2011       [EdwardBurns, KerryBishé, MarshaDietlein]
# 4806          2013         [EricMabius, KristinBooth, CrystalLowe]
# 4807          2012          [DanielHenney, ElizaCoupe, BillPaxton]
# 4808          2005  [DrewBarrymore, BrianHerzlinger, CoreyFeldman]
#
#                     crew                                               tags
# 0         [JamesCameron]  [Action, Adventure, Fantasy, ScienceFiction, I...
# 1        [GoreVerbinski]  [Adventure, Fantasy, Action, Captain, Barbossa...
# 2            [SamMendes]  [Action, Adventure, Crime, A, cryptic, message...
# 3     [ChristopherNolan]  [Action, Crime, Drama, Thriller, Following, th...
# 4        [AndrewStanton]  [Action, Adventure, ScienceFiction, John, Cart...
# ...                  ...                                                ...
# 4804   [RobertRodriguez]  [Action, Crime, Thriller, El, Mariachi, just, ...
# 4805       [EdwardBurns]  [Comedy, Romance, A, newlywed, couple's, honey...
# 4806        [ScottSmith]  [Comedy, Drama, Romance, TVMovie, "Signed,, Se...
# 4807        [DanielHsia]  [When, ambitious, New, York, attorney, Sam, is...
# 4808   [BrianHerzlinger]  [Documentary, Ever, since, the, second, grade,...
#
# [4800 rows x 12 columns]

# %% [markdown]
# #### 새로운 데이터셋 final
# * popularity을 넣은 이유 -> 나중에 상위 10개 영화를 popularity기준으로 정렬하기 위해서.

# %%
final = DF[['id','title','tags','popularity','release_date']]
final
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags  popularity  \
# 0     [Action, Adventure, Fantasy, ScienceFiction, I...  150.437577
# 1     [Adventure, Fantasy, Action, Captain, Barbossa...  139.082615
# 2     [Action, Adventure, Crime, A, cryptic, message...  107.376788
# 3     [Action, Crime, Drama, Thriller, Following, th...  112.312950
# 4     [Action, Adventure, ScienceFiction, John, Cart...   43.926995
# ...                                                 ...         ...
# 4804  [Action, Crime, Thriller, El, Mariachi, just, ...   14.269792
# 4805  [Comedy, Romance, A, newlywed, couple's, honey...    0.642552
# 4806  [Comedy, Drama, Romance, TVMovie, "Signed,, Se...    1.444476
# 4807  [When, ambitious, New, York, attorney, Sam, is...    0.857008
# 4808  [Documentary, Ever, since, the, second, grade,...    1.929883
#
#       release_date
# 0             2009
# 1             2007
# 2             2015
# 3             2012
# 4             2012
# ...            ...
# 4804          1992
# 4805          2011
# 4806          2013
# 4807          2012
# 4808          2005
#
# [4800 rows x 5 columns]

# %% [markdown]
# #### tags로 묶여있는 정보들 모두 소문자로 변경

# %%
final['tags'] = final['tags'].apply(lambda x: [word.lower() for word in x])
# Out:
# <ipython-input-25-1fb856f4ab5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['tags'] = final['tags'].apply(lambda x: [word.lower() for word in x])

# %%
final.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags  popularity  release_date
# 0  [action, adventure, fantasy, sciencefiction, i...  150.437577          2009
# 1  [adventure, fantasy, action, captain, barbossa...  139.082615          2007
# 2  [action, adventure, crime, a, cryptic, message...  107.376788          2015
# 3  [action, crime, drama, thriller, following, th...  112.312950          2012
# 4  [action, adventure, sciencefiction, john, cart...   43.926995          2012

# %% [markdown]
# #### 리스트에서 다시 문자형으로 변경

# %%
final['tags'] = final['tags'].apply(lambda x: " ".join(x))
# Out:
# <ipython-input-27-7824520c8602>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['tags'] = final['tags'].apply(lambda x: " ".join(x))

# %%
final.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags  popularity  release_date
# 0  action adventure fantasy sciencefiction in the...  150.437577          2009
# 1  adventure fantasy action captain barbossa, lon...  139.082615          2007
# 2  action adventure crime a cryptic message from ...  107.376788          2015
# 3  action crime drama thriller following the deat...  112.312950          2012
# 4  action adventure sciencefiction john carter is...   43.926995          2012

# %% [markdown]
# #### 널값 있는지 확인

# %%
final.isna().sum()
# Out:
# id              0
# title           0
# tags            0
# popularity      0
# release_date    0
# dtype: int64

# %% [markdown]
# #### 각 단어의 어간 추출하고 공백으로 구분하여 문자열 반환

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []

    for i in text.split():
        y.append(ps.stem(i))

    return " ".join(y)

# %%
final['tags'] = final['tags'].apply(stem)
# Out:
# <ipython-input-32-ca5a47576b92>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['tags'] = final['tags'].apply(stem)

# %%
final
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags  popularity  \
# 0     action adventur fantasi sciencefict in the 22n...  150.437577
# 1     adventur fantasi action captain barbossa, long...  139.082615
# 2     action adventur crime a cryptic messag from bo...  107.376788
# 3     action crime drama thriller follow the death o...  112.312950
# 4     action adventur sciencefict john carter is a w...   43.926995
# ...                                                 ...         ...
# 4804  action crime thriller el mariachi just want to...   14.269792
# 4805  comedi romanc a newlyw couple' honeymoon is up...    0.642552
# 4806  comedi drama romanc tvmovi "signed, sealed, de...    1.444476
# 4807  when ambiti new york attorney sam is sent to s...    0.857008
# 4808  documentari ever sinc the second grade when he...    1.929883
#
#       release_date
# 0             2009
# 1             2007
# 2             2015
# 3             2012
# 4             2012
# ...            ...
# 4804          1992
# 4805          2011
# 4806          2013
# 4807          2012
# 4808          2005
#
# [4800 rows x 5 columns]

# %% [markdown]
# #### 코사인유사도

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words = 'english')
count_matrix = count.fit_transform(final['tags'])
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_matrix, count_matrix)
cosine_sim

# %% [markdown]
# #### recommend_pop 모델
# * 코사인 유사도 기반으로 가장 유사한 상위 10개 영화를 popularity 기준으로 내림차순 정렬 (인기 순으로 출력)

# %%
def recommendations_pop(title, cosine_sim=cosine_sim):
  # 영화 제목을 통해서 전체 데이터 기준 그 영화의 index 값을 얻기
  idx = final[final['title'] == title].index[0]
  # 코싸인 유사도 매틕스(cosine_sim)에서 idx에 해당하는 데이터를 (idx, 유사도)형식으로 출력
  sim_scores = list(enumerate(cosine_sim[idx]))
  # 코사인 유사도 기준으로 내림차순 정렬
  sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)
  # 자기 자신을 제외한 10개의 추천 영화
  sim_scores = sim_scores[1:11]
  # 추천 영화 목록 10개의 인덱스 정보 추출
  movie_indices = [i[0] for i in sim_scores]
  # 인기 순으로 정렬
  recommended_movies = final.iloc[movie_indices].nlargest(10, 'popularity')

  for movie in recommended_movies['title']:
      print(movie)

# %%
recommendations_pop('Avatar')

# %% [markdown]
# #### recommend_year 모델
# * 코사인 유사도 기반으로 가장 유사한 상위 10개 영화를 released_date 기준으로 내림차순 정렬 (최신 영화 순으로 출력)

# %%
def recommendations_year(title, cosine_sim=cosine_sim):
  # 영화 제목을 통해서 전체 데이터 기준 그 영화의 index 값을 얻기
  idx = final[final['title'] == title].index[0]
  # 코싸인 유사도 매틕스(cosine_sim)에서 idx에 해당하는 데이터를 (idx, 유사도)형식으로 출력
  sim_scores = list(enumerate(cosine_sim[idx]))
  # 코사인 유사도 기준으로 내림차순 정렬
  sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)
  # 자기 자신을 제외한 10개의 추천 영화
  sim_scores = sim_scores[1:11]
  # 추천 영화 목록 10개의 인덱스 정보 추출
  movie_indices = [i[0] for i in sim_scores]
  # 개봉 년도 기준으로 정렬
  recommended_movies = final.iloc[movie_indices].nlargest(10, 'release_date')

  for movie in recommended_movies['title']:
      print(movie)

# %%
recommendations_year('Avatar')
